# %%
def intro():
    print ('earlycode group of  company payrol')
    Fname = input('employee\'s Name:')
    Fname = int(input('employee\'s level'))
def current_payment():
    basic = int(input('Basic Salary: '))
    HA = basic * 0.15
    LA = basic * 0.25
    TA = basic * 0.15
    TRA = basic * 0.35
    MA = basic * 0.20
    PF = basic * 0.15
    NETPAY = basic + HA + LA + TA + TRA + MA
    GROSSPAY = NETPAY - PF
    
    print(f'''Basic Salary:{basic}
 Housin Allowance:{HA}
 Leave Allowance: {LA}
 Travelling Allowance: {TA}
 Transport Allowance: {TRA}
 Medical ALlowance: {MA}
 Provident Funds: {PF}
 NetPay: {NETPAY}
 GrossPay:{GROSSPAY}
    ''')
def updated_payment_level1():
    basic = int(input('Basic Salary: '))
    ubasic = (basic * 0.05) + basic
    uHA = basic * 0.15
    uLA = basic * 0.25
    uTA = basic * 0.15
    uTRA = basic * 0.35
    uMA = basic * 0.20
    uPF = basic * 0.15
    uNETPAY = ubasic + uHA + uLA + uTA + uTRA + uMA
    uGROSSPAY = uNETPAY - uPF
    print(f'''Basic Salary:{ubasic}
 Housin Allowance:{uHA}
 Leave Allowance: {uLA}
 Travelling Allowance: {uTA}
 Transport Allowance: {uTRA}
 Medical ALlowance: {uMA}
 Provident Funds: {uPF}
 NetPay: {uNETPAY}
 GrossPay:{uGROSSPAY}
    ''')
def updated_payment_level2():
    basic = int(input('Basic Salary: '))
    ubasic = (basic * 0.10) + basic
    uHA = basic * 0.15
    uLA = basic * 0.25
    uTA = basic * 0.15
    uTRA = basic * 0.35
    uMA = basic * 0.20
    uPF = basic * 0.15
    uNETPAY = ubasic + uHA + uLA + uTA + uTRA + uMA
    uGROSSPAY = uNETPAY - uPF
    
    print(f'''Basic Salary:{ubasic}
 Housin Allowance:{uHA}
 Leave Allowance: {uLA}
 Travelling Allowance: {uTA}
 Transport Allowance: {uTRA}
 Medical ALlowance: {uMA}
 Provident Funds: {uPF}
 NetPay: {uNETPAY}
 GrossPay:{uGROSSPAY}
    ''')
def updated_payment_level3():
    basic = int(input('Basic Salary: '))
    ubasic = (basic * 0.15) + basic
    uHA = basic * 0.15
    uLA = basic * 0.25
    uTA = basic * 0.15
    uTRA = basic * 0.35
    uMA = basic * 0.20
    uPF = basic * 0.15
    uNETPAY = ubasic + uHA + uLA + uTA + uTRA + uMA
    uGROSSPAY = uNETPAY - uPF
    print(f'''Basic Salary:{ubasic}
 Housin Allowance:{uHA}
 Leave Allowance: {uLA}
 Travelling Allowance: {uTA}
 Transport Allowance: {uTRA}
 Medical ALlowance: {uMA}
 Provident Funds: {uPF}
 NetPay: {uNETPAY}
 GrossPay:{uGROSSPAY}
    ''')
def updated_payment_level3():
    basic = int(input('Basic Salary: '))
    ubasic = (basic * 0.20) + basic
    uHA = basic * 0.15
    uLA = basic * 0.25
    uTA = basic * 0.15
    uTRA = basic * 0.35
    uMA = basic * 0.20
    uPF = basic * 0.15
    uNETPAY = ubasic + uHA + uLA + uTA + uTRA + uMA
    uGROSSPAY = uNETPAY - uPF
    print(f'''Basic Salary:{ubasic}
 Housin Allowance:{uHA}
 Leave Allowance: {uLA}
 Travelling Allowance: {uTA}
 Transport Allowance: {uTRA}
 Medical ALlowance: {uMA}
 Provident Funds: {uPF}
 NetPay: {uNETPAY}
 GrossPay:{uGROSSPAY}
    ''')
def updated_payment_level4():
    basic = int(input('Basic Salary: '))
    ubasic = (basic * 0.25) + basic
    uHA = basic * 0.15
    uLA = basic * 0.25
    uTA = basic * 0.15
    uTRA = basic * 0.35
    uMA = basic * 0.20
    uPF = basic * 0.15
    uNETPAY = ubasic + uHA + uLA + uTA + uTRA + uMA
    uGROSSPAY = uNETPAY - uPF
    print(f'''Basic Salary:{ubasic}
 Housin Allowance:{uHA}
 Leave Allowance: {uLA}
 Travelling Allowance: {uTA}
 Transport Allowance: {uTRA}
 Medical ALlowance: {uMA}
 Provident Funds: {uPF}
 NetPay: {uNETPAY}
 GrossPay:{uGROSSPAY}
    ''')
def updated_payment_level5():
    basic = int(input('Basic Salary: '))
    ubasic = (basic * 0.30) + basic
    uHA = basic * 0.15
    uLA = basic * 0.25
    uTA = basic * 0.15
    uTRA = basic * 0.35
    uMA = basic * 0.20
    uPF = basic * 0.15
    uNETPAY = ubasic + uHA + uLA + uTA + uTRA + uMA
    uGROSSPAY = uNETPAY - uPF
    print(f'''Basic Salary:{ubasic}
 Housin Allowance:{uHA}
 Leave Allowance: {uLA}
 Travelling Allowance: {uTA}
 Transport Allowance: {uTRA}
 Medical ALlowance: {uMA}
 Provident Funds: {uPF}
 NetPay: {uNETPAY}
 GrossPay:{uGROSSPAY}
    ''')
def updated_payment_others():
    basic = int(input('Basic Salary: '))
    ubasic = (basic * 0.35) + basic
    uHA = basic * 0.15
    uLA = basic * 0.25
    uTA = basic * 0.15
    uTRA = basic * 0.35
    uMA = basic * 0.20
    uPF = basic * 0.15
    uNETPAY = ubasic + uHA + uLA + uTA + uTRA + uMA
    uGROSSPAY = uNETPAY - uPF
    print(f'''Basic Salary:{ubasic}
 Housin Allowance:{uHA}
 Leave Allowance: {uLA}
 Travelling Allowance: {uTA}
 Transport Allowance: {uTRA}
 Medical ALlowance: {uMA}
 Provident Funds: {uPF}
 NetPay: {uNETPAY}
 GrossPay:{uGROSSPAY}
    ''')

# %%
intro()
current_payment()
# Out:
# earlycode group of  company payrol
# employee's Name:Eni
# employee's level10
# Basic Salary: 35
# Basic Salary:35
#  Housin Allowance:5.25
#  Leave Allowance: 8.75
#  Travelling Allowance: 5.25
#  Transport Allowance: 12.25
#  Medical ALlowance: 7.0
#  Provident Funds: 5.25
#  NetPay: 73.5
#  GrossPay:68.25

# %%
intro()
updated_payment_level1()
# Out:
# earlycode group of  company payrol
# employee's Name:jame
# employee's level1
# Basic Salary: 20000
# Basic Salary:21000.0
#  Housin Allowance:3000.0
#  Leave Allowance: 5000.0
#  Travelling Allowance: 3000.0
#  Transport Allowance: 7000.0
#  Medical ALlowance: 4000.0
#  Provident Funds: 3000.0
#  NetPay: 43000.0
#  GrossPay:40000.0
